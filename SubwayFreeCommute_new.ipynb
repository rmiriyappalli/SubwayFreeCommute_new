# %% [markdown]
# ## This Notebook will be used to come up the solution to find a job without taking subway using the foursquare location data

# %% [markdown]
# ##### Problem Description

# %% [markdown]
# I live far from New York City and have been commuting 5 hours in a day from home to work by switching Metro-North and multiple subways. Its been many years have done the painful commute and left the job finally. However want to start work again and only the good jobs exists in City which match to my experience.

# %% [markdown]
# ##### Solution to the Problem

# %% [markdown]
# By using Foursquare  location data that I can find closest jobs from Grand Central by setting my main location as Grand Central and point of interest is jobs that are match to my experience which are Wealth management firms. Once I can find list of organizations that have likes and description details in terms of diversity.

# %% [markdown]
# #### Who would be interested

# %% [markdown]
#  The users that are facing same issues like me can use this application to run in 3 steps of input information can be useful to target the jobs that are close to desired location and interested industry with meaningful business description and likes

# %% [markdown]
# ### Data Source is Foursquare New York City Locations and details of each entry

# %% [markdown]
# Import Libaries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values


print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::anaconda==5.3.1=py37_0
#   - defaults/linux-64::astropy==3.0.4=py37h14c3975_0
#   - defaults/linux-64::bkcharts==0.2=py37_0
#   - defaults/linux-64::blaze==0.11.3=py37_0
#   - defaults/linux-64::bokeh==0.13.0=py37_0
#   - defaults/linux-64::bottleneck==1.2.1=py37h035aef0_1
#   - defaults/linux-64::dask==0.19.1=py37_0
#   - defaults/linux-64::datashape==0.5.4=py37_1
#   - defaults/linux-64::mkl-service==1.1.2=py37h90e4bf4_5
#   - defaults/linux-64::numba==0.39.0=py37h04863e7_0
#   - defaults/linux-64::numexpr==2.6.8=py37hd89afb7_0
#   - defaults/linux-64::odo==0.5.1=py37_0
#   - defaults/linux-64::pytables==3.4.4=py37ha205bf6_0
#   - defaults/linux-64::pytest-arraydiff==0.2=py37h39e3cac_0
#   - defaults/linux-64::pytest-astropy==0.4.0=py37_0
#   - defaults/linux-64::pytest-doctestplus==0.1.3=py37_0
# ...

# %%
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# ...
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::anaconda==5.3.1=py37_0
#   - defaults/linux-64::astropy==3.0.4=py37h14c3975_0
#   - defaults/linux-64::bkcharts==0.2=py37_0
#   - defaults/linux-64::blaze==0.11.3=py37_0
#   - defaults/linux-64::bokeh==0.13.0=py37_0
#   - defaults/linux-64::bottleneck==1.2.1=py37h035aef0_1
#   - defaults/linux-64::dask==0.19.1=py37_0
#   - defaults/linux-64::datashape==0.5.4=py37_1
#   - defaults/linux-64::mkl-service==1.1.2=py37h90e4bf4_5
#   - defaults/linux-64::numba==0.39.0=py37h04863e7_0
#   - defaults/linux-64::numexpr==2.6.8=py37hd89afb7_0
#   - defaults/linux-64::odo==0.5.1=py37_0
#   - defaults/linux-64::pytables==3.4.4=py37ha205bf6_0
#   - defaults/linux-64::pytest-arraydiff==0.2=py37h39e3cac_0
#   - defaults/linux-64::pytest-astropy==0.4.0=py37_0
#   - defaults/linux-64::pytest-doctestplus==0.1.3=py37_0
# ...

# %% [markdown]
# created Foursquare credentials

# %%
CLIENT_ID = 'PWZNNP0OOEYULB0CAL23TLQ1VSCVUC40CYX5KYCPS5RI3MM2'
CLIENT_SECRET = 'MZSMMUVIQGJEBQPXKWHE1ZOEBRJXL4RXNXPGEFEM0X4UHHYJ'
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: PWZNNP0OOEYULB0CAL23TLQ1VSCVUC40CYX5KYCPS5RI3MM2
# CLIENT_SECRET:MZSMMUVIQGJEBQPXKWHE1ZOEBRJXL4RXNXPGEFEM0X4UHHYJ

# %% [markdown]
# ## My location of main street is Grand Central Terminal. Use GC latitude and longitude coordinates.
# ## In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent foursquare_agent, as shown below.

# %%
address = 'Grand Central Terminal, New York, NY'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude, location)
# Out:
# 40.7527012 -73.9772498736336 GCT, 89, East 42nd Street, Midtown East, Manhattan Community Board 5, Manhattan, New York County, NYC, New York, 10017, USA

# %% [markdown]
# ### Set the search query string which is desired company as Wealth Management Company

# %%
search_query = 'Wealth Management Company'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Wealth Management Company .... OK!

# %% [markdown]
# ## Build search url with search string and credentials and other necessary info to call Foursquare venue API call

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=PWZNNP0OOEYULB0CAL23TLQ1VSCVUC40CYX5KYCPS5RI3MM2&client_secret=MZSMMUVIQGJEBQPXKWHE1ZOEBRJXL4RXNXPGEFEM0X4UHHYJ&ll=40.7527012,-73.9772498736336&v=20180604&query=Wealth Management Company&radius=500&limit=30'

# %% [markdown]
# ## send request and observe the data once we get json response convert to dataframe to read all the data output from API then filter to required columns to use the information to find additional details API calls

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d0c2207787dba0033f820a1'},
#  'response': {'venues': [{'id': '5c1a8172c8b2fb0039d3a629',
#     'name': 'The FCG Wealth Management Group - Morgan Stanley',
#     'location': {'address': '522 5th Ave Fl 15',
#      'lat': 40.7546909,
#      'lng': -73.9805466,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7546909,
#        'lng': -73.9805466}],
#      'distance': 355,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['522 5th Ave Fl 15',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '503287a291d4c4b30a586d65',
#       'name': 'Financial or Legal Service',
#       'pluralName': 'Financial or Legal Services',
#       'shortName': 'Financial / Legal',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head(10)
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '503287a291d4c4b30a586d65', 'name': 'F...    False
# 1  [{'id': '503287a291d4c4b30a586d65', 'name': 'F...    False
# 2  [{'id': '5453de49498eade8af355881', 'name': 'B...    False
# 3  [{'id': '503287a291d4c4b30a586d65', 'name': 'F...    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
# 5  [{'id': '503287a291d4c4b30a586d65', 'name': 'F...    False
# 6  [{'id': '503287a291d4c4b30a586d65', 'name': 'F...    False
# 7  [{'id': '503287a291d4c4b30a586d65', 'name': 'F...    False
# 8  [{'id': '503287a291d4c4b30a586d65', 'name': 'F...    False
# 9  [{'id': '503287a291d4c4b30a586d65', 'name': 'F...    False
#
#                          id       location.address location.cc location.city  \
# 0  5c1a8172c8b2fb0039d3a629      522 5th Ave Fl 15          US      New York
# 1  5c999b43d1a402002c25d3a8  122 E 42nd St Rm 1610          US      New York
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0    The FCG Wealth Management Group - Morgan Stanley
# 1                         PRB Wealth Management, LLC.
# 2                            Zodiac Wealth Management
# 3                   Mercer Advisors Wealth Management
# 4                     Merrill Lynch Wealth Management
# 5    Rafaela Gittens - TIAA Wealth Management Advisor
# 6        Ardis Owens - TIAA Wealth Management Advisor
# 7          Todd Toro - TIAA Wealth Management Advisor
# 8       Regina Moran - TIAA Wealth Management Advisor
# 9   Vyacheslav Kuzmin - TIAA Wealth Management Adv...
# 10    Joseph Di Vico - TIAA Wealth Management Advisor
# 11   Eugene Gershman - TIAA Wealth Management Advisor
# 12  Jermaine Guthrie - TIAA Wealth Management Advisor
# 13    Eliahou Haroun - TIAA Wealth Management Advisor
# 14   Brannigan Judge - TIAA Wealth Management Advisor
# 15       Debra Iorio - TIAA Wealth Management Advisor
# ...

# %% [markdown]
# ## Visualize the data

# %%
dataframe_filtered.name
# Out:
# 0      The FCG Wealth Management Group - Morgan Stanley
# 1                           PRB Wealth Management, LLC.
# 2                              Zodiac Wealth Management
# 3                     Mercer Advisors Wealth Management
# 4                       Merrill Lynch Wealth Management
# 5      Rafaela Gittens - TIAA Wealth Management Advisor
# 6          Ardis Owens - TIAA Wealth Management Advisor
# 7            Todd Toro - TIAA Wealth Management Advisor
# 8         Regina Moran - TIAA Wealth Management Advisor
# 9     Vyacheslav Kuzmin - TIAA Wealth Management Adv...
# 10      Joseph Di Vico - TIAA Wealth Management Advisor
# 11     Eugene Gershman - TIAA Wealth Management Advisor
# 12    Jermaine Guthrie - TIAA Wealth Management Advisor
# 13      Eliahou Haroun - TIAA Wealth Management Advisor
# 14     Brannigan Judge - TIAA Wealth Management Advisor
# 15         Debra Iorio - TIAA Wealth Management Advisor
# 16     Rasheed Defense - TIAA Wealth Management Advisor
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Methodology

# %% [markdown]
# I used the Folium to draw the visualization to understand that how close they are and howmany of Wealth Management firsm close to Grand Central

# %% [markdown]
# ### Result

# %% [markdown]
# # explore details abou the company and likes and description of the company before submitting to job posting

# %%
venue_id = '5c999b43d1a402002c25d3a8' # ID of first Wealth Management Company
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/5c999b43d1a402002c25d3a8?client_id=PWZNNP0OOEYULB0CAL23TLQ1VSCVUC40CYX5KYCPS5RI3MM2&client_secret=MZSMMUVIQGJEBQPXKWHE1ZOEBRJXL4RXNXPGEFEM0X4UHHYJ&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'likes', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'description', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto'])
# {'id': '5c999b43d1a402002c25d3a8',
#  'name': 'PRB Wealth Management, LLC.',
#  'contact': {'phone': '2128677730',
#   'formattedPhone': '(212) 867-7730',
#   'twitter': 'prbwealthmngmt',
#   'facebook': '546619172097658',
#   'facebookName': 'PRB Wealth Management'},
#  'location': {'address': '122 E 42nd St Rm 1610',
#   'lat': 40.751316,
#   'lng': -73.97657720000001,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.751316,
#     'lng': -73.97657720000001}],
#   'postalCode': '10168',
#   'cc': 'US',
#   'city': 'New York',
#   'state': 'NY',
#   'country': 'United States',
#   'formattedAddress': ['122 E 42nd St Rm 1610',
# ...

# %% [markdown]
# ### Observations and Recommendations

# %% [markdown]
# The response is not very useful when it comes to understand if company is diversified or employee satisfaction etc which can be improved to collect this information or add those details based on the new sruvey on each employers

# %% [markdown]
# ### Conclusion

# %% [markdown]
# I am able to see how far each organizatin from Grand Central and if there are any job openinegs that I can apply to shorten the commute

# %% [markdown]
# ### Presentation

# %% [markdown]
# Attached the github link with PPT
